# %%
import numpy as np # linear algebra
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('newdata.csv', sep=',', names = ["ITEM_NO","ACCTG_YEAR","ACCTG_PERIOD","WHSE_CODE","TRAN_CODE","QTY"])

# %%
df
# Out:
#        ITEM_NO  ACCTG_YEAR  ACCTG_PERIOD  WHSE_CODE TRAN_CODE   QTY
# 0           0%        2014             1         10         P  25.0
# 1           0%        2014             1         10         T  12.0
# 2           0%        2014             1         20         R   2.0
# 3           0%        2014             1         30         P  25.0
# 4           0%        2014             1         30         R  10.0
# 5           0%        2014             1         30         S  10.0
# 6           0%        2014             2         10         T   1.0
# 7           0%        2014             2         20         R   1.0
# 8           0%        2014             2         20         S   1.0
# 9           0%        2014             3         10         T   2.0
# 10          0%        2014             3         20         R   2.0
# 11          0%        2014             3         20         S   2.0
# 12          0%        2014             4         10         T   2.0
# ...
